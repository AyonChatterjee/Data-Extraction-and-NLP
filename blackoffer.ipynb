# %%
#import necessary pacakages
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
import re
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\chatt\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\chatt\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Reading the dataset

df = pd.read_excel("Input.xlsx")
df
# Out:
#               URL_ID                                                URL
# 0    Netclan20241017  https://insights.blackcoffer.com/ai-and-ml-bas...
# 1    Netclan20241018  https://insights.blackcoffer.com/enhancing-fro...
# 2    Netclan20241019  https://insights.blackcoffer.com/roas-dashboar...
# 3    Netclan20241020  https://insights.blackcoffer.com/efficient-pro...
# 4    Netclan20241021  https://insights.blackcoffer.com/development-o...
# ..               ...                                                ...
# 142  Netclan20241159  https://insights.blackcoffer.com/population-an...
# 143  Netclan20241160  https://insights.blackcoffer.com/google-lsa-ap...
# 144  Netclan20241161  https://insights.blackcoffer.com/healthcare-da...
# 145  Netclan20241162  https://insights.blackcoffer.com/budget-sales-...
# 146  Netclan20241163  https://insights.blackcoffer.com/amazon-buy-bo...
#
# [147 rows x 2 columns]

# %%
# Load Stop words and Master Dictionary

# Folder containing stopwords files
stopwords_folder = 'StopWords'

# Load stopwords from all .txt files in the folder
stop_words = set()
for filename in os.listdir(stopwords_folder):
    if filename.endswith('.txt'):
        with open(os.path.join(stopwords_folder, filename), 'r') as file:
            stop_words.update(file.read().splitlines())

positive_words = set(open('MasterDictionary/positive-words.txt').read().split())
negative_words = set(open('MasterDictionary/negative-words.txt').read().split())

# %%
# Defining the utility functions

def clean_text(text):
    text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove punctuation
    words = word_tokenize(text.lower())       # Tokenize and convert to lowercase
    cleaned = [word for word in words if word not in stop_words]
    return cleaned

# %% [markdown]
# Calculating the sentiment scores

# %%
def calculate_sentiment_scores(cleaned_words):
    positive_score = sum(1 for word in cleaned_words if word in positive_words)
    negative_score = sum(1 for word in cleaned_words if word in negative_words)
    polarity_score = (positive_score - negative_score) / ((positive_score + negative_score) + 1e-6)
    subjectivity_score = (positive_score + negative_score) / (len(cleaned_words) + 1e-6)
    return positive_score, negative_score, polarity_score, subjectivity_score

# %% [markdown]
# Analysis of Readibility

# %%
from nltk.tokenize import sent_tokenize

def analyze_readability(text):
    sentences = sent_tokenize(text)
    words = word_tokenize(text)
    num_sentences = len(sentences)
    num_words = len(words)
    num_complex_words = sum(1 for word in words if syllable_count(word) > 2)
    avg_sentence_length = num_words / num_sentences
    percentage_complex_words = num_complex_words / num_words
    fog_index = 0.4 * (avg_sentence_length + percentage_complex_words)
    return avg_sentence_length, percentage_complex_words, fog_index

# %%
# Syllable Count Per Word

def syllable_count(word):
    word = word.lower()
    count = len(re.findall(r'[aeiouy]', word))
    if word.endswith(('es', 'ed')) and len(word) > 2:
        count -= 1
    return max(count, 1)

# %%
# Personal Pronouns

def personal_pronouns_count(text):
    pronouns = re.findall(r'\b(I|we|my|ours|us)\b', text, re.IGNORECASE)
    return len(pronouns)

# %%
# Average Word Length

def average_word_length(words):
    total_length = sum(len(word) for word in words)
    return total_length / len(words) if words else 0

# %%
# Function to extract text from a url

def extract_text_from_url(url):
    try:
        page = requests.get(url)
        if page.status_code != 200:
            return None
        soup = BeautifulSoup(page.text, 'html.parser')
        title = soup.find('h1').text.strip() if soup.find('h1') else ''
        paragraphs = [p.text.strip() for p in soup.find_all('p')]
        content = title + ' ' + ' '.join(paragraphs)
        return content
    except Exception as e:
        print(f"Error fetching URL {url}: {e}")
        return None

# %%
# Main function to process a URL and return analysis

def process_url(url):
    text = extract_text_from_url(url)
    if not text:
        return None

    cleaned_words = clean_text(text)
    positive_score, negative_score, polarity_score, subjectivity_score = calculate_sentiment_scores(cleaned_words)
    avg_sentence_length, percentage_complex_words, fog_index = analyze_readability(text)
    num_words = len(cleaned_words)
    num_complex_words = sum(1 for word in cleaned_words if syllable_count(word) > 2)
    syllables_per_word = sum(syllable_count(word) for word in cleaned_words) / num_words
    pronoun_count = personal_pronouns_count(text)
    avg_word_length = average_word_length(cleaned_words)

    return {
        'URL_ID': None,
        'URL': None,     
        'Positive Score': positive_score,
        'Negative Score': negative_score,
        'Polarity Score': polarity_score,
        'Subjectivity Score': subjectivity_score,
        'Average Sentence Length': avg_sentence_length,
        'Percentage of Complex Words': percentage_complex_words,
        'Fog Index': fog_index,
        'AVG NUMBER OF WORDS PER SENTENCE': avg_sentence_length, 
        'COMPLEX WORD COUNT': num_complex_words,
        'Word Count': num_words,
        'Syllable Count Per Word': syllables_per_word,
        'Personal Pronouns': pronoun_count,
        'Average Word Length': avg_word_length
    }

# %%
# Read the input DataFrame and process URLs
def analyze_urls(input_df, output_file):
    results = []

    for index, row in input_df.iterrows():
        url_id = row['URL_ID']
        url = row['URL']
        print(f"Processing URL_ID {url_id}: {url}")

        analysis = process_url(url)
        if analysis:
            analysis['URL_ID'] = url_id
            analysis['URL'] = url
            results.append(analysis)
        else:
            print(f"Failed to process URL_ID {url_id}: {url}")

    # Create a DataFrame from results
    results_df = pd.DataFrame(results)
    

    column_order = ['URL_ID', 'URL', 'Positive Score', 'Negative Score', 'Polarity Score', 'Subjectivity Score',
                    'Average Sentence Length', 'Percentage of Complex Words', 'Fog Index',
                    'AVG NUMBER OF WORDS PER SENTENCE', 'COMPLEX WORD COUNT',
                    'Word Count', 'Syllable Count Per Word', 'Personal Pronouns', 'Average Word Length']

    results_df.to_excel(output_file, index=False)

# %%
if __name__ == "__main__":
    
    # Output Excel file
    output_excel = "Output Data Structure.xlsx"

    # Perform analysis
    analyze_urls(df, output_excel)
# Out:
# Processing URL_ID Netclan20241017: https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/
# Processing URL_ID Netclan20241018: https://insights.blackcoffer.com/enhancing-front-end-features-and-functionality-for-improved-user-experience-and-dashboard-accuracy-in-partner-hospital-application/
# Processing URL_ID Netclan20241019: https://insights.blackcoffer.com/roas-dashboard-for-campaign-wise-google-ads-budget-tracking-using-google-ads-ap/
# Processing URL_ID Netclan20241020: https://insights.blackcoffer.com/efficient-processing-and-analysis-of-financial-data-from-pdf-files-addressing-formatting-inconsistencies-and-ensuring-data-integrity-for-a-toyota-dealership-management-firm/
# Processing URL_ID Netclan20241021: https://insights.blackcoffer.com/development-of-ea-robot-for-automated-trading/
# Processing URL_ID Netclan20241022: https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/
# Processing URL_ID Netclan20241023: https://insights.blackcoffer.com/enhancing-front-end-features-and-functionality-for-improved-user-experience-and-dashboard-accuracy-in-partner-hospital-application/
# Processing URL_ID Netclan20241024: https://insights.blackcoffer.com/roas-dashboard-for-campaign-wise-google-ads-budget-tracking-using-google-ads-ap/
# Processing URL_ID Netclan20241025: https://insights.blackcoffer.com/efficient-processing-and-analysis-of-financial-data-from-pdf-files-addressing-formatting-inconsistencies-and-ensuring-data-integrity-for-a-toyota-dealership-management-firm/
# Processing URL_ID Netclan20241026: https://insights.blackcoffer.com/transforming-and-managing-a-large-scale-sql-pedigree-database-to-neo4j-graph-db/
# Processing URL_ID Netclan20241027: https://insights.blackcoffer.com/enhancing-model-accuracy-from-58-to-over-90-strategies-for-improving-predictive-performance/
# Processing URL_ID Netclan20241028: https://insights.blackcoffer.com/securing-sensitive-financial-data-with-privacy-preserving-machine-learning-for-predictive-analytics/
# Processing URL_ID Netclan20241029: https://insights.blackcoffer.com/enhancing-data-collection-for-research-institutions-addressing-survey-fatigue-and-incorporating-verbal-communication-for-richer-insights/
# Processing URL_ID Netclan20241030: https://insights.blackcoffer.com/analyzing-the-impact-of-positive-emotions-and-pandemic-severity-on-mental-health-and-resilience-among-entrepreneurs-insights-and-predictive-modeling/
# Processing URL_ID Netclan20241031: https://insights.blackcoffer.com/dynamic-brand-centric-dashboard-for-automotive-dealerships-pdf-to-financial-insights-with-flask-react-architecture-and-aws-cloud-hosting/
# Processing URL_ID Netclan20241032: https://insights.blackcoffer.com/cloud-based-data-modeling-and-analysis-platform-with-drag-and-drop-interface-and-openai-api-integration-for-simulation-insights/
# Processing URL_ID Netclan20241033: https://insights.blackcoffer.com/voter-profile-analysis-and-search-application-for-targeted-campaign-engagement-using-government-voter-data/
# Processing URL_ID Netclan20241034: https://insights.blackcoffer.com/bert-based-classification-of-individuals-and-organizations-into-two-categories-using-natural-language-processing/
# Processing URL_ID Netclan20241035: https://insights.blackcoffer.com/comprehensive-analysis-of-solana-and-ethereum-contributors-using-github-api-with-comparative-study-of-1000-random-github-profiles/
# Processing URL_ID Netclan20241036: https://insights.blackcoffer.com/powerbi-rest-api-fetching-dataflow-and-refresh-schedules-with-semantic-models/
# Processing URL_ID Netclan20241037: https://insights.blackcoffer.com/automated-job-data-import-and-management-solution-for-enhanced-efficiency/
# Processing URL_ID Netclan20241038: https://insights.blackcoffer.com/data-analytics-and-optimization-solution-for-enhancing-renewable-energy-efficiency/
# Processing URL_ID Netclan20241039: https://insights.blackcoffer.com/time-series-analysis-and-trend-forecasting-solution-for-predicting-news-trends/
# Processing URL_ID Netclan20241040: https://insights.blackcoffer.com/advanced-data-visualization-solutions-for-monitoring-key-business-metrics-with-integrated-interactive-dashboards/
# Processing URL_ID Netclan20241041: https://insights.blackcoffer.com/advanced-patient-data-analysis-solution-for-trend-identification-and-improved-healthcare-outcome/
# Processing URL_ID Netclan20241042: https://insights.blackcoffer.com/anomaly-detection-and-analysis-for-enhanced-data-integrity-and-user-experience-on-bright-datas-website/
# Processing URL_ID Netclan20241043: https://insights.blackcoffer.com/building-custom-tflite-models-and-benchmarking-on-voxl2-chips/
# Processing URL_ID Netclan20241044: https://insights.blackcoffer.com/sports-prediction-model-for-multiple-sports-leagues/
# Processing URL_ID Netclan20241045: https://insights.blackcoffer.com/efficient-coach-allocation-system-for-sports-coaching-organization/
# Processing URL_ID Netclan20241046: https://insights.blackcoffer.com/data-studio-dashboard-with-a-data-pipeline-tool-synced-with-podio-using-custom-webhooks-and-google-cloud-function-2/
# Processing URL_ID Netclan20241047: https://insights.blackcoffer.com/ai-driven-backend-for-audio-to-text-conversion-and-analytical-assessment-in-pharmaceutical-practice/
# Processing URL_ID Netclan20241048: https://insights.blackcoffer.com/cloud-based-web-application-for-financial-data-processing-and-visualization-of-sp-500-metrics/
# Processing URL_ID Netclan20241049: https://insights.blackcoffer.com/department-wise-kpi-tracking-dashboard-with-technician-performance-analysis-for-atoz-dependable-service/
# Processing URL_ID Netclan20241050: https://insights.blackcoffer.com/steps-to-convert-a-node-js-api-to-python-for-aws-lambda-deployment/
# Processing URL_ID Netclan20241051: https://insights.blackcoffer.com/building-an-analytics-dashboard-with-a-pdf-parsing-pipeline-for-data-extraction/
# Processing URL_ID Netclan20241052: https://insights.blackcoffer.com/building-a-real-time-log-file-visualization-dashboard-in-kibana/
# Processing URL_ID Netclan20241053: https://insights.blackcoffer.com/analyzing-the-impact-of-female-ceo-appointments-on-company-stock-prices/
# Processing URL_ID Netclan20241054: https://insights.blackcoffer.com/ai-chatbot-using-llm-langchain-llama/
# Processing URL_ID Netclan20241055: https://insights.blackcoffer.com/healthcare-ai-chatbot-using-llama-llm-langchain/
# Processing URL_ID Netclan20241056: https://insights.blackcoffer.com/ai-bot-audio-to-audio/
# Processing URL_ID Netclan20241057: https://insights.blackcoffer.com/recommendation-engine-for-insurance-sector-to-expand-business-in-the-rural-area/
# Processing URL_ID Netclan20241058: https://insights.blackcoffer.com/data-from-crm-via-zapier-to-google-sheets-dynamic-to-powerbi/
# Processing URL_ID Netclan20241059: https://insights.blackcoffer.com/data-warehouse-to-google-data-studio-looker-dashboard/
# Processing URL_ID Netclan20241060: https://insights.blackcoffer.com/crm-monday-com-via-zapier-to-power-bi-dashboard/
# Processing URL_ID Netclan20241061: https://insights.blackcoffer.com/monday-com-to-kpi-dashboard-to-manage-view-and-generate-insights-from-the-crm-data/
# Processing URL_ID Netclan20241062: https://insights.blackcoffer.com/data-management-for-a-political-saas-application/
# Processing URL_ID Netclan20241063: https://insights.blackcoffer.com/google-lsa-ads-google-local-service-ads-etl-tools-and-dashboards/
# Processing URL_ID Netclan20241064: https://insights.blackcoffer.com/ad-networks-marketing-campaign-data-dashboard-in-looker-google-data-studio/
# Processing URL_ID Netclan20241065: https://insights.blackcoffer.com/analytical-solution-for-a-tech-firm/
# Processing URL_ID Netclan20241066: https://insights.blackcoffer.com/ai-solution-for-a-technology-information-and-internet-firm/
# Processing URL_ID Netclan20241067: https://insights.blackcoffer.com/ai-and-nlp-based-solutions-to-automate-data-discovery-for-venture-capital-and-private-equity-principals/
# Processing URL_ID Netclan20241068: https://insights.blackcoffer.com/an-etl-solution-for-an-internet-publishing-firm/
# Processing URL_ID Netclan20241069: https://insights.blackcoffer.com/ai-based-algorithmic-trading-bot-for-forex/
# Processing URL_ID Netclan20241070: https://insights.blackcoffer.com/equity-waterfalls-model-based-saas-application-for-real-estate-sector/
# Processing URL_ID Netclan20241071: https://insights.blackcoffer.com/ai-solutions-for-foreign-exchange-an-automated-algo-trading-tool/
# Processing URL_ID Netclan20241072: https://insights.blackcoffer.com/ai-agent-development-and-deployment-in-jina-ai/
# Processing URL_ID Netclan20241073: https://insights.blackcoffer.com/golden-record-a-knowledge-graph-database-approach-to-unfold-discovery-using-neo4j/
# Processing URL_ID Netclan20241074: https://insights.blackcoffer.com/advanced-ai-for-trading-automation/
# Processing URL_ID Netclan20241075: https://insights.blackcoffer.com/create-a-knowledge-graph-to-provide-real-time-analytics-recommendations-and-a-single-source-of-truth/
# Processing URL_ID Netclan20241076: https://insights.blackcoffer.com/advanced-ai-for-thermal-person-detection/
# Processing URL_ID Netclan20241077: https://insights.blackcoffer.com/advanced-ai-for-road-cam-threat-detection/
# Processing URL_ID Netclan20241078: https://insights.blackcoffer.com/advanced-ai-for-pedestrian-crossing-safety/
# Processing URL_ID Netclan20241079: https://insights.blackcoffer.com/handgun-detection-using-yolo/
# Processing URL_ID Netclan20241080: https://insights.blackcoffer.com/using-graph-technology-to-create-single-customer-view/
# Processing URL_ID Netclan20241081: https://insights.blackcoffer.com/car-detection-in-satellite-images/
# Processing URL_ID Netclan20241082: https://insights.blackcoffer.com/building-a-physics-informed-neural-network-for-circuit-evaluation/
# Processing URL_ID Netclan20241083: https://insights.blackcoffer.com/connecting-mongodb-database-to-power-bi-dashboard-dashboard-automation/
# Processing URL_ID Netclan20241084: https://insights.blackcoffer.com/data-transformation/
# Processing URL_ID Netclan20241085: https://insights.blackcoffer.com/e-commerce-store-analysis-purchase-behavior-ad-spend-conversion-traffic-etc/
# Processing URL_ID Netclan20241086: https://insights.blackcoffer.com/kpi-dashboard-for-accountants/
# Processing URL_ID Netclan20241087: https://insights.blackcoffer.com/return-on-advertising-spend-dashboard-marketing-automation-and-analytics-using-etl-and-dashboard/
# Processing URL_ID Netclan20241088: https://insights.blackcoffer.com/ranking-customer-behaviours-for-business-strategy/
# Processing URL_ID Netclan20241089: https://insights.blackcoffer.com/algorithmic-trading-for-multiple-commodities-markets-like-forex-metals-energy-etc/
# Processing URL_ID Netclan20241090: https://insights.blackcoffer.com/trading-bot-for-forex/
# Processing URL_ID Netclan20241091: https://insights.blackcoffer.com/python-model-for-the-analysis-of-sector-specific-stock-etfs-for-investment-purposes%ef%bf%bc/
# Processing URL_ID Netclan20241092: https://insights.blackcoffer.com/medical-classification/
# Processing URL_ID Netclan20241093: https://insights.blackcoffer.com/design-develop-bert-question-answering-model-explanations-with-visualization/
# Processing URL_ID Netclan20241094: https://insights.blackcoffer.com/design-and-develop-solution-to-anomaly-detection-classification-problems/
# Processing URL_ID Netclan20241095: https://insights.blackcoffer.com/an-etl-solution-for-currency-data-to-google-big-query/
# Processing URL_ID Netclan20241096: https://insights.blackcoffer.com/etl-and-mlops-infrastructure-for-blockchain-analytics/
# Processing URL_ID Netclan20241097: https://insights.blackcoffer.com/an-agent-based-model-of-a-virtual-power-plant-vpp/
# Processing URL_ID Netclan20241098: https://insights.blackcoffer.com/transform-api-into-sdk-library-and-widget/
# Processing URL_ID Netclan20241099: https://insights.blackcoffer.com/integration-of-a-product-to-a-cloud-based-crm-platform/
# Processing URL_ID Netclan20241100: https://insights.blackcoffer.com/a-web-based-dashboard-for-the-filtered-data-retrieval-of-land-records/
# Processing URL_ID Netclan20241101: https://insights.blackcoffer.com/integration-of-video-conferencing-data-to-the-existing-web-app/
# Processing URL_ID Netclan20241102: https://insights.blackcoffer.com/design-develop-an-app-in-retool-which-shows-the-progress-of-the-added-video/
# Processing URL_ID Netclan20241103: https://insights.blackcoffer.com/auvik-connectwise-integration-in-grafana/
# Processing URL_ID Netclan20241104: https://insights.blackcoffer.com/data-integration-and-big-data-performance-using-elk-stack/
# Processing URL_ID Netclan20241105: https://insights.blackcoffer.com/web-data-connector/
# Processing URL_ID Netclan20241106: https://insights.blackcoffer.com/an-app-for-updating-the-email-id-of-the-user-and-stripe-refund-tool-using-retool/
# Processing URL_ID Netclan20241107: https://insights.blackcoffer.com/an-ai-ml-based-web-application-that-detects-the-correctness-of-text-in-a-given-video/
# Processing URL_ID Netclan20241108: https://insights.blackcoffer.com/website-tracking-and-insights-using-google-analytics-google-tag-manager/
# Processing URL_ID Netclan20241109: https://insights.blackcoffer.com/dashboard-to-track-the-analytics-of-the-website-using-google-analytics-and-google-tag-manager/
# Processing URL_ID Netclan20241110: https://insights.blackcoffer.com/power-bi-dashboard-on-operations-transactions-and-marketing-embedding-the-dashboard-to-web-app/
# Processing URL_ID Netclan20241111: https://insights.blackcoffer.com/nft-data-automation-looksrare-and-etl-tool/
# Processing URL_ID Netclan20241112: https://insights.blackcoffer.com/optimize-the-data-scraper-program-to-easily-accommodate-large-files-and-solve-oom-errors/
# Processing URL_ID Netclan20241113: https://insights.blackcoffer.com/making-a-robust-way-to-sync-data-from-airtables-to-mongodb-using-python-etl-solution/
# Processing URL_ID Netclan20241114: https://insights.blackcoffer.com/incident-duration-prediction-infrastructure-and-real-estate/
# Processing URL_ID Netclan20241115: https://insights.blackcoffer.com/statistical-data-analysis-of-reinforced-concrete/
# Processing URL_ID Netclan20241116: https://insights.blackcoffer.com/database-normalization-segmentation-with-google-data-studio-dashboard-insights/
# Processing URL_ID Netclan20241117: https://insights.blackcoffer.com/power-bi-dashboard-to-drive-insights-from-complex-data-to-generate-business-insights/
# Processing URL_ID Netclan20241118: https://insights.blackcoffer.com/real-time-dashboard-to-monitor-infrastructure-activity-and-machines/
# Processing URL_ID Netclan20241119: https://insights.blackcoffer.com/electric-vehicles-ev-load-management-system-to-forecast-energy-demand/
# Processing URL_ID Netclan20241120: https://insights.blackcoffer.com/power-bi-data-driven-map-dashboard/
# Processing URL_ID Netclan20241121: https://insights.blackcoffer.com/google-local-service-ads-lsa-leads-dashboard/
# Processing URL_ID Netclan20241122: https://insights.blackcoffer.com/aws-lex-voice-and-chatbot/
# Processing URL_ID Netclan20241123: https://insights.blackcoffer.com/metabridges-api-decentraland-integration/
# Processing URL_ID Netclan20241124: https://insights.blackcoffer.com/microsoft-azure-chatbot-with-luis-language-understanding/
# Processing URL_ID Netclan20241125: https://insights.blackcoffer.com/impact-of-news-media-and-press-on-innovation-startups-and-investments/
# Processing URL_ID Netclan20241126: https://insights.blackcoffer.com/aws-quicksight-reporting-dashboard/
# Processing URL_ID Netclan20241127: https://insights.blackcoffer.com/google-data-studio-dashboard-for-marketing-ads-and-traction-data/
# Processing URL_ID Netclan20241128: https://insights.blackcoffer.com/gangala-in-e-commerce-big-data-etl-elt-solution-and-data-warehouse/
# Processing URL_ID Netclan20241129: https://insights.blackcoffer.com/big-data-solution-to-an-online-multivendor-marketplace-ecommerce-business/
# Processing URL_ID Netclan20241130: https://insights.blackcoffer.com/creating-a-custom-report-and-dashboard-using-the-data-got-from-atera-api/
# Processing URL_ID Netclan20241131: https://insights.blackcoffer.com/azure-data-lake-and-power-bi-dashboard/
# Processing URL_ID Netclan20241132: https://insights.blackcoffer.com/google-data-studio-pipeline-with-gcp-mysql/
# Processing URL_ID Netclan20241133: https://insights.blackcoffer.com/quickbooks-dashboard-to-find-patterns-in-finance-sales-and-forecasts/
# Processing URL_ID Netclan20241134: https://insights.blackcoffer.com/marketing-sales-and-financial-data-business-dashboard-wink-report/
# Processing URL_ID Netclan20241135: https://insights.blackcoffer.com/react-native-apps-in-the-development-portfolio/
# Processing URL_ID Netclan20241136: https://insights.blackcoffer.com/a-leading-firm-website-seo-optimization/
# Processing URL_ID Netclan20241137: https://insights.blackcoffer.com/a-leading-hospitality-firm-in-the-usa-website-seo-optimization/
# Processing URL_ID Netclan20241138: https://insights.blackcoffer.com/a-leading-firm-in-the-usa-website-seo-optimization/
# Processing URL_ID Netclan20241139: https://insights.blackcoffer.com/a-leading-musical-instrumental-website-seo-optimization/
# Processing URL_ID Netclan20241140: https://insights.blackcoffer.com/a-leading-firm-in-the-usa-seo-and-website-optimization/
# Processing URL_ID Netclan20241141: https://insights.blackcoffer.com/immigration-datawarehouse-ai-based-recommendations/
# Processing URL_ID Netclan20241142: https://insights.blackcoffer.com/lipsync-automation-for-celebrities-and-influencers/
# Processing URL_ID Netclan20241143: https://insights.blackcoffer.com/key-audit-matters-predictive-modeling/
# Processing URL_ID Netclan20241144: https://insights.blackcoffer.com/splitting-of-songs-into-its-vocals-and-instrumental/
# Processing URL_ID Netclan20241145: https://insights.blackcoffer.com/ai-and-ml-technologies-to-evaluate-learning-assessments/
# Processing URL_ID Netclan20241146: https://insights.blackcoffer.com/datawarehouse-and-recommendations-engine-for-airbnb/
# Processing URL_ID Netclan20241147: https://insights.blackcoffer.com/real-estate-data-warehouse/
# Processing URL_ID Netclan20241148: https://insights.blackcoffer.com/traction-dashboards-of-marketing-campaigns-and-posts/
# Processing URL_ID Netclan20241149: https://insights.blackcoffer.com/google-local-service-ads-lsa-data-warehouse/
# Processing URL_ID Netclan20241150: https://insights.blackcoffer.com/google-local-service-ads-missed-calls-and-messages-automation-tool/
# Processing URL_ID Netclan20241151: https://insights.blackcoffer.com/marketing-ads-leads-call-status-data-tool-to-bigquery/
# Processing URL_ID Netclan20241152: https://insights.blackcoffer.com/marketing-analytics-to-automate-leads-call-status-and-reporting/
# Processing URL_ID Netclan20241153: https://insights.blackcoffer.com/callrail-analytics-leads-report-alert/
# Processing URL_ID Netclan20241154: https://insights.blackcoffer.com/marketing-automation-tool-to-notify-lead-details-to-clients-over-email-and-phone/
# Processing URL_ID Netclan20241155: https://insights.blackcoffer.com/data-etl-local-service-ads-leads-to-bigquery/
# Processing URL_ID Netclan20241156: https://insights.blackcoffer.com/marbles-stimulation-using-python/
# Processing URL_ID Netclan20241157: https://insights.blackcoffer.com/stocktwits-data-structurization/
# Processing URL_ID Netclan20241158: https://insights.blackcoffer.com/sentimental-analysis-on-shareholder-letter-of-companies/
# Processing URL_ID Netclan20241159: https://insights.blackcoffer.com/population-and-community-survey-of-america/
# Processing URL_ID Netclan20241160: https://insights.blackcoffer.com/google-lsa-api-data-automation-and-dashboarding/
# Processing URL_ID Netclan20241161: https://insights.blackcoffer.com/healthcare-data-analysis/
# Processing URL_ID Netclan20241162: https://insights.blackcoffer.com/budget-sales-kpi-dashboard-using-power-bi/
# Processing URL_ID Netclan20241163: https://insights.blackcoffer.com/amazon-buy-bot-an-automation-ai-tool-to-auto-checkouts/
